# %%
import pandas as pd
import numpy as np
from datetime import timedelta
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import json
import bisect



import datetime



# %matplotlib inline

# %%
arr = []
vals = []


for j in range(5000):
    vals.append([])
    arr = []
    for i in range(50):
        bisect.insort(arr , np.random.normal())
        if(len(arr) > 20):
            arr.pop(0)
        vals[j].append(np.min(arr))
res = np.mean(vals , axis=0)

# %%
res[-1]
# Out:
# 0.5290451492300149

# %%
res
# Out:
# array([-2.55641735e-02, -5.84234747e-01, -8.51205422e-01, -1.02906589e+00,
#        -1.16041994e+00, -1.27213193e+00, -1.36380467e+00, -1.43355081e+00,
#        -1.49631496e+00, -1.55519891e+00, -1.60737506e+00, -1.64656110e+00,
#        -1.68917656e+00, -1.72297709e+00, -1.75778713e+00, -1.78369218e+00,
#        -1.81366246e+00, -1.83944823e+00, -1.86664487e+00, -1.88913113e+00,
#        -1.44326405e+00, -1.19441265e+00, -1.01570126e+00, -8.77216172e-01,
#        -7.65006376e-01, -6.70838709e-01, -5.87685658e-01, -5.12329719e-01,
#        -4.43042674e-01, -3.82436769e-01, -3.27779342e-01, -2.77040142e-01,
#        -2.28086689e-01, -1.84730459e-01, -1.42000397e-01, -1.03681502e-01,
#        -6.64082846e-02, -3.09466948e-02,  1.28079436e-03,  3.31171167e-02,
#         6.28621819e-02,  9.17032843e-02,  1.20278090e-01,  1.46799754e-01,
#         1.71428842e-01,  1.94482398e-01,  2.17477938e-01,  2.40377553e-01,
#         2.61469790e-01,  2.82780830e-01])

# %%
plt.plot(res)

# %%
plt.plot(vals)

# %%
vals
# Out:
# [[0.0,
#   0.034025584298504746,
#   0.04000503847802602,
#   0.04000503847802602,
#   0.08171140210203579,
#   0.08171140210203579,
#   0.08171140210203579,
#   0.08171140210203579,
#   0.08171140210203579,
#   0.08171140210203579,
#   0.08171140210203579,
#   0.08171140210203579,
#   0.08171140210203579,
#   0.08171140210203579,
#   0.08171140210203579,
#   0.13371254014968798,
#   0.13371254014968798,
#   0.1800181641720861,
#   0.1800181641720861,
#   0.1800181641720861,
#   0.1800181641720861,
#   0.21180431002278838,
#   0.2530467840140354,
#   0.2530467840140354,
#   0.3202323131785435,
#   0.3576480512966108,
#   0.3576480512966108,
#   0.3576480512966108,
#   0.3576480512966108,
#   0.3576480512966108,
#   0.4124313471349499,
#   0.4472214117328953,
#   0.4472214117328953,
#   0.4472457437776137,
#   0.511177295754628,
#   0.5175000596539637,
#   0.5175000596539637,
#   0.5195242024147633,
#   0.5824169936216778,
#   0.5975566907244848,
#   0.5975566907244848,
# ...
